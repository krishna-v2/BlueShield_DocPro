# %%
from pyzbar.pyzbar import decode
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread(r'C:\Users\vineet\OneDrive - V2 Tech Ventures Pvt Ltd\blueshield\BS_Test_Data_2022_04_14\filled_forms\processed\2_filled.png')

# %%
plt.imshow(img)

# %%
hs, he = 220, 300
ws, we = 100, 700
bc_img = img[hs:he, ws:we, :]

# %%
plt.imshow(bc_img)

# %%
barcode_data = decode(bc_img)

# %%
barcode_data[0].data[:12]
# Out:
# b'000000000002'
